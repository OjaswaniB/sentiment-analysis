# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                  transcript
# david     In this 2023 comedy special, David Nihill humo...
# gabriel   [man] Can you please state your name? Martin M...
# george    George Carlin: I’m Glad I’m Dead (2024) is a c...
# jon       In an interview conducted by Jon Stewart, Geor...
# kate      Whoa! Okay, yeah. Good. Okay, don’t embarrass ...
# kevin     Kevin James: Irregardless (2024) In Kevin Jame...
# leanne    Leanne Morgan: I’m Every Woman (2023) In “I’m ...
# lewis     Lewis Black: Tragically, I Need You (2023) is ...
# louis     “Louis C.K.: At The Dolby” is Louis C.K.’s thi...
# matt      In his second hour-long comedy special, “Matth...
# pete      Pete Davidson: Turbo Fonzarelli (2024)\nReleas...
# roseanne  “Roseanne Barr: Cancel This!” is a stand-up co...
# sammy     In this humorous and politically charged stand...
# shane     Shane Gillis’ debut stand-up comedy special, r...
# stavros   In his stand-up comedy special Live at the Lod...

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['jon']
ali_text[:200]
# Out:
# 'In an interview conducted by Jon Stewart, George Carlin talks about various aspects of his life and career, reflecting upon his childhood, formative influences, and his perspectives on comedy and crea'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'In': ['an', 'Las'],
#  'an': ['interview',
#   'innate',
#   'advertising',
#   'experimental',
#   'environment',
#   'uneducated',
#   'obsessive',
#   'advertising',
#   'experimental',
#   'actress,',
#   'edge,',
#   'entertainer',
#   'artist',
#   'obligation',
#   'afterthought.',
#   'also'],
#  'interview': ['conducted', 'also', 'with'],
#  'conducted': ['by'],
#  'by': ['Jon', 'his', 'a', 'his', 'hand', 'the', 'giving', 'giving', 'the'],
#  'Jon': ['Stewart,'],
#  'Stewart,': ['George'],
#  'George': ['Carlin', 'Carlin’s', 'on', 'Carlin', 'Carlin!'],
#  'Carlin': ['talks', 'felt', 'highlights', 'acknowledges', 'should'],
#  'talks': ['about'],
#  'about': ['various', 'what', 'language,', 'business.'],
#  'various': ['aspects'],
#  'aspects': ['of'],
#  'of': ['his',
#   'performance',
#   'eliciting',
#   'his',
#   'his',
#   'not',
#   'his',
#   'pursuits',
#   'drugs',
#   'which',
#   'the',
#   'his',
#   'adults',
#   'respect,',
#   'listening',
#   'things,',
#   'rhetoric.',
#   'the',
#   'his',
#   'Shakespeare',
#   'the',
#   '1935,',
#   'the',
#   'controlling,',
#   'corporal',
#   'an',
#   'them',
#   'like',
#   'what',
#   'those',
#   'its',
#   'the',
#   'course,',
#   'his',
#   'luck',
#   'people',
#   'stuck',
#   'a',
#   'this',
#   'truth',
#   'let,',
#   'stuff,',
#   'judicious',
#   'the',
#   'balls',
#   'these',
#   'the',
#   'that',
#   'time,',
#   'time',
#   'it,',
#   'people.',
#   'people',
#   'people',
#   'people,',
#   'people',
#   'best-selling',
#   'this',
#   '‘The',
#   'Interest,’',
#   'the'],
#  'his': ['life',
#   'childhood,',
#   'perspectives',
#   'comedic',
#   'parents,',
#   'grandfather,',
#   'mother,',
#   'life.',
#   'creative',
#   'battles',
#   'eventual',
#   'life',
#   'family',
#   'dedicated',
#   'path',
#   'remarkable',
#   'adult',
#   'hat.',
#   'way,',
#   'own,',
#   'film',
#   'personal'],
#  'life': ['and', 'than', 'that’s', 'where', 'I', 'the'],
#  'and': ['career,',
#   'his',
#   'creativity.',
#   'the',
#   'creativity.',
#   'a',
#   'his',
#   'eschewed',
#   'nurturing',
#   'connections',
#   'his',
#   'insightful',
#   'Bob',
#   'you',
#   'have',
#   'clever?’',
#   'you',
#   'approval',
#   'a',
#   'you',
#   'father',
#   'dialects',
#   'tell',
#   'have',
#   'through',
#   'use',
#   'all',
#   'listen',
#   'it’s',
#   'he',
#   'most',
#   'my',
#   'he',
#   'he',
#   'was',
#   'the',
#   'I',
#   'the',
#   'she,',
#   'that',
#   'so',
#   'from',
#   'a',
#   'we',
#   'their',
#   'being',
#   'then',
#   'be',
#   'not',
#   'it’s',
#   'intellect',
#   'alcohol',
#   'these',
#   'keep',
#   'the',
#   'it’s',
#   'there’s',
#   'I’ll',
#   'you',
#   'they’re',
#   'I’m',
#   'alcohol,',
#   'I',
#   'I',
#   'it’s',
#   'Florence',
#   'you',
#   'hit',
#   'then',
#   'foremost,',
#   'an',
#   'you',
#   'that’s',
#   'looking',
#   'going',
#   'trying',
#   'it',
#   'everything.',
#   'the',
#   'everything,',
#   'the',
#   'they',
#   'see',
#   'concert',
#   'you’re',
#   'everybody',
#   'to',
#   'can',
#   'armbands',
#   'fight',
#   'a',
#   'despise',
#   'they’re',
#   'you',
#   'listen,',
#   'B’s',
#   'C’s',
#   'D’s,',
#   'this',
#   'their',
#   'to',
#   'thank',
#   'I',
#   'advocates',
#   'improvisational',
#   'chilling',
#   'their'],
#  'career,': ['reflecting'],
#  'reflecting': ['upon'],
#  'upon': ['his'],
#  'childhood,': ['formative'],
#  'formative': ['influences,'],
#  'influences,': ['and'],
#  'perspectives': ['on'],
#  'on': ['comedy',
#   'the',
#   'the',
#   'the',
#   'The',
#   'the',
#   'an',
#   'route,',
#   'yourself,',
#   'me,'],
#  'comedy': ['and', 'now?'],
#  'creativity.': ['From', 'Additionally,'],
#  'From': ['a'],
#  'a': ['young',
#   'dual',
#   'law',
#   'writer,',
#   'prominent',
#   'sense',
#   'candid',
#   'distinct',
#   'kid',
#   'reward,',
#   'psychic',
#   'kid',
#   'little',
#   'mother',
#   'punch',
#   'musician,',
#   'fascination',
#   'kid?',
#   'form',
#   'policeman',
#   'lot',
#   'champion',
#   'difficult',
#   'top',
#   'fire',
#   'bit,',
#   'typical',
#   'bit',
#   'life',
#   'lot',
#   'little,',
#   'natural',
#   'degree',
#   'hangover.',
#   'lot',
#   'lot',
#   'bit',
#   'genius',
#   'canard',
#   'long',
#   'lot',
#   'window',
#   'big',
#   'joint',
#   'month,',
#   'whole',
#   'point',
#   'couple',
#   'journey',
#   'lot,',
#   'little',
#   'different',
#   'lot',
#   'person,',
#   'wonderful',
#   'sense',
#   'week.',
#   'group',
#   'common',
#   'list',
#   'family',
#   'multitude',
#   'dopey',
#   'little',
#   'pleasure',
#   'part',
#   'little.',
#   'lot,',
#   'captivating'],
#  'young': ['age,', 'man.'],
#  'age,': ['Carlin'],
#  'felt': ['an'],
#  'innate': ['inclination'],
#  'inclination': ['toward'],
#  'toward': ['the'],
#  'the': ['world',
#   'art',
#   'nurturing',
#   'impact',
#   'conventional',
#   'typical',
#   'discovery',
#   'allure',
#   'indispensable',
#   'intricacies',
#   'world,',
#   'lens',
#   'attention',
#   'bus',
#   'rocks,',
#   'years',
#   'way',
#   'question,',
#   'same',
#   'turn',
#   'century,',
#   'course',
#   'works',
#   'joy',
#   'mahogany',
#   'Dale',
#   'direction',
#   'picture,',
#   'dirty',
#   'awful',
#   'business',
#   'finest',
#   'same',
#   'same',
#   'nuns',
#   'nuns,',
#   'nuns',
#   'street,',
#   'awful',
#   'awful',
#   'church',
#   'edges,',
#   'rails,',
#   'desire',
#   'willingness',
#   'people',
#   'drug',
#   'pleasure',
#   'pain',
#   'price',
#   'balance',
#   'other',
#   'intellect',
#   'drugs,',
#   'wild',
#   'drugs',
#   'vistas',
#   'things',
#   'canvas,',
#   'fun.',
#   'grueling,',
#   'only',
#   'only',
#   'people',
#   'audiences',
#   'tickets',
#   'theaters',
#   'audience,',
#   'whole',
#   'convention,',
#   'festival',
#   'universe',
#   'feeling',
#   'way,',
#   'family.',
#   'approval–',
#   'only',
#   'only',
#   'wonderful–',
#   'director',
#   'most',
#   'Holocaust',
#   'Von'],
#  'world': ['of'],
#  'performance': ['and'],
#  'art': ['of', 'involved'],
#  'eliciting': ['laughter'],
#  'laughter': ['from'],
#  'from': ['others.', 'the', 'that', 'being', 'Canadian'],
#  'others.': ['He'],
#  'He': ['attributes', 'attended', 'credits'],
#  'attributes': ['much'],
#  'much': ['of', 'edgy', 'for'],
#  'comedic': ['beginnings'],
#  'beginnings': ['to'],
#  'to': ['the',
#   'the',
#   'recovery.',
#   'be',
#   'stand',
#   'your',
#   'go',
#   'sing',
#   'go,',
#   'go',
#   'watch?',
#   'control',
#   'school,',
#   'school',
#   'her,',
#   'not',
#   'pull',
#   'do',
#   'work',
#   'me,',
#   'this:',
#   'die,',
#   'live',
#   'have',
#   'look',
#   'bring',
#   'live',
#   'open',
#   'broaden',
#   'do',
#   'sort',
#   'get',
#   'keep',
#   'any',
#   'Picasso,',
#   'be',
#   'be',
#   'challenge',
#   'be',
#   'be',
#   'call',
#   'put',
#   'do',
#   'go',
#   'my',
#   'go',
#   'Stevens',
#   'come',
#   'the',
#   'a',
#   'be',
#   'visit',
#   'say,',
#   'what',
#   'not',
#   'say',
#   'spend',
#   'be',
#   'know',
#   'it.',
#   'Hollywood',
#   'date',
#   'life'],
#  'nurturing': ['environment', 'his'],
#  'environment': ['provided', 'that'],
#  'provided': ['by', 'by'],
#  'parents,': ['individuals'],
#  'individuals': ['who'],
#  'who': ['exuded',
#   'possessed',
#   'held',
#   'were',
#   'deal',
#   'had',
#   'can',
#   'became',
#   'have–',
#   'feel'],
#  'exuded': ['both'],
#  'both': ['humor', 'of'],
#  'humor': ['and'],
#  'Additionally,': ['Carlin'],
#  'highlights': ['the'],
#  'impact': ['of'],
#  'grandfather,': ['who', 'whom'],
#  'possessed': ['a'],
#  'dual': ['identity'],
#  'identity': ['as'],
#  'as': ['a', 'an', 'seen', 'I', 'a', 'you', 'far', 'just'],
#  'law': ['enforcement'],
#  'enforcement': ['officer'],
#  'officer': ['and'],
#  'writer,': ['and'],
#  'mother,': ['who'],
#  'held': ['a', 'greater'],
#  'prominent': ['role'],
#  'role': ['as'],
#  'advertising': ['executive', 'executive'],
#  'executive': ['in', 'secretary,'],
#  'in': ['his',
#   'fostering',
#   'his',
#   'helping',
#   'Ireland,',
#   'New',
#   'the',
#   'advertising,',
#   'that',
#   'the',
#   'the',
#   'content',
#   'this',
#   'his',
#   'giving',
#   'that',
#   'it.',
#   'your',
#   'Vegas,',
#   'it,',
#   'Albuquerque,',
#   'the',
#   'comedy',
#   'there,',
#   'planes',
#   'their',
#   'this',
#   'the',
#   'wrestling'],
#  'life.': ['Carlin’s'],
#  'Carlin’s': ['journey', 'personal', 'unguarded'],
#  'journey': ['through', 'involved', 'in'],
#  'through': ['the', 'the', 'all'],
#  'conventional': ['educational'],
#  'educational': ['system'],
#  'system': ['was', 'and'],
#  'was': ['marked',
#   'given,',
#   'a',
#   'an',
#   'a',
#   'great.',
#   'out',
#   'brilliant,',
#   'a',
#   'given',
#   'very',
#   '2',
#   '5',
#   'gone.',
#   'very',
#   'heartbroken',
#   'a',
#   'an',
#   'just',
#   'an',
#   'just',
#   'okay',
#   'that.'],
#  'marked': ['by', '*'],
#  'sense': ['of', 'of'],
#  'not': ['quite',
#   'just',
#   'just',
#   'do',
#   'be',
#   'be',
#   'always',
#   'just',
#   'around',
#   'a',
#   'comparing',
#   'come',
#   'come.',
#   'committed',
#   'being',
#   'dead,',
#   'just',
#   'only',
#   'be'],
#  'quite': ['fitting'],
#  'fitting': ['in.'],
#  'in.': ['He', ''],
#  'attended': ['an'],
#  'experimental': ['school', 'progressive'],
#  'school': ['that', 'on', 'that'],
#  'that': ['boldly',
#   'proved',
#   'held',
#   'you',
#   'morning',
#   'always',
#   'you',
#   'ever',
#   'direction',
#   'I',
#   'didn’t',
#   'and',
#   'day',
#   'and',
#   'hurt',
#   'point,',
#   'the',
#   'by',
#   'most',
#   'as',
#   'would',
#   'sort',
#   'a',
#   'you',
#   'I',
#   'place',
#   'is',
#   'I’m',
#   'it’s',
#   'brings'],
#  'boldly': ['discarded'],
#  'discarded': ['the'],
#  'typical': ['grading', 'Catholic'],
#  'grading': ['system'],
#  'eschewed': ['corporal'],
#  'corporal': ['punishment,', 'punishment,'],
#  'punishment,': ['an', 'it'],
#  'proved': ['instrumental'],
#  'instrumental': ['in'],
#  'fostering': ['and'],
#  'creative': ['tendencies.'],
#  'tendencies.': ['The'],
#  'The': ['interview', 'Tonight', 'thing', 'next'],
#  'also': ['gets', 'partly', 'well,'],
#  'gets': ['into'],
#  'into': ['Carlin’s', 'when'],
#  'personal': ['struggles', 'touch'],
#  'struggles': ['with'],
#  'with': ['addiction,',
#   'substances.',
#   'language,',
#   'the',
#   'rhetoric,',
#   'the',
#   'it',
#   'it',
#   'pot,',
#   'that',
#   'the',
#   'the',
#   'a',
#   'you',
#   'Tucker',
#   'Jonathan'],
#  'addiction,': ['offering'],
#  'offering': ['a'],
#  'candid': ['examination'],
#  'examination': ['of'],
#  'battles': ['with'],
#  'substances.': ['He'],
#  'credits': ['his'],
#  'eventual': ['triumph'],
#  'triumph': ['over'],
#  'over': ['addiction', '800'],
#  'addiction': ['to'],
#  'discovery': ['of'],
#  'pursuits': ['and'],
#  'connections': ['that'],
#  'greater': ['significance'],
#  'significance': ['in'],
#  'than': ['the', 'fair…'],
#  'allure': ['of'],
#  'drugs': ['or', 'and', 'are'],
#  'or': ['alcohol.', 'wherever'],
#  'alcohol.': ['Throughout'],
#  'Throughout': ['this'],
#  'this': ['challenging',
#   'thing',
#   'and',
#   'world,',
#   'doesn’t',
#   'creativity',
#   'thing',
#   'is',
#   'guy.',
#   'big',
#   'is',
#   'has',
#   'show,'],
#  'challenging': ['journey,'],
#  'journey,': ['Carlin', 'from'],
#  'acknowledges': ['the'],
#  'indispensable': ['support'],
#  'support': ['provided'],
#  'family': ['and', 'life', 'of'],
#  'dedicated': ['fanbase,'],
#  'fanbase,': ['both'],
#  'which': ['played'],
#  'played': ['pivotal'],
#  'pivotal': ['roles'],
#  'roles': ['in'],
#  'helping': ['him'],
#  'him': ['maintain', 'either.', 'when'],
#  'maintain': ['his'],
#  'path': ['to'],
#  'recovery.': ['George'],
#  'unguarded': ['and'],
#  'insightful': ['responses'],
#  'responses': ['offer'],
#  'offer': ['a'],
#  'distinct': ['vantage'],
#  'vantage': ['point'],
#  'point': ['on', 'in'],
#  'intricacies': ['of'],
#  'world,': ['as', 'thought', 'part'],
#  'seen': ['through'],
#  'lens': ['of'],
#  'remarkable': ['career.'],
#  'career.': ['*'],
#  '*': ['*', '*', '\xa0', '*', '*', 'Your', 'Name*'],
#  '\xa0': ['JON'],
#  'JON': ['STEWART:'],
#  'STEWART:': ['When'],
#  'When': ['you'],
#  'you': ['were',
#   'wanted',
#   'think',
#   'know,',
#   'cute?',
#   'cute',
#   'know,',
#   'find',
#   'can',
#   'just',
#   'keep',
#   'know,',
#   'don’t',
#   'never',
#   'know,',
#   'know,',
#   'weave',
#   'look',
#   'look',
#   'went',
#   'started',
#   'don’t',
#   'understand?',
#   'do',
#   'know,',
#   'gotta',
#   'do',
#   'time',
#   'increase',
#   'pay,',
#   'would',
#   'need',
#   'who',
#   'need',
#   'out.',
#   'lose',
#   'have',
#   'know,',
#   'have',
#   'do',
#   'leave',
#   'still',
#   'still',
#   'at',
#   'could',
#   'could',
#   'could',
#   'still',
#   'wouldn’t',
#   'gonna',
#   'don’t',
#   'in',
#   'trying',
#   'know,',
#   'know?',
#   'to',
#   'in',
#   'could',
#   'know?',
#   'feel',
#   'feel',
#   'know,',
#   'know,',
#   'feel',
#   'know,',
#   'get',
#   'say,',
#   'say,',
#   'know,',
#   'look',
#   'can',
#   'know?',
#   'know',
#   'said?’',
#   'say,',
#   'think',
#   'would',
#   'can',
#   'can',
#   'see,',
#   'have',
#   'enough',
#   'and',
#   'very',
#   'a',
#   'are',
#   'very'],
#  'were': ['a', 'very', 'great.'],
#  'kid': ['growing', 'and'],
#  'growing': ['up,', 'on'],
#  'up,': ['you', 'and', 'and', 'and'],
#  'wanted': ['to', 'to', 'to'],
#  'be': ['Danny',
#   'silly',
#   'determined',
#   'said,',
#   'turned',
#   'altered',
#   'hidden.',
#   'frequent',
#   'on',
#   'going',
#   'seeking',
#   'fresh,',
#   'new,',
#   'in',
#   '60,',
#   'a',
#   'published.'],
#  'Danny': ['Kaye,'],
#  'Kaye,': ['and'],
#  'Bob': ['Hope.'],
#  'Hope.': ['So,'],
#  'So,': ['look,', 'you'],
#  'look,': ['how'],
#  'how': ['do'],
#  'do': ['you',
#   'accents',
#   'is',
#   'oftentimes',
#   'that',
#   'with',
#   'hard',
#   'seem',
#   'seem',
#   'is',
#   'find',
#   'you',
#   'you',
#   'your',
#   'you',
#   'morning',
#   'this',
#   'it',
#   'some',
#   'this,'],
#  'think': ['this', 'I', 'so', 'there’s', 'it'],
#  'thing': ['is', 'that', 'you', 'going.'],
#  'is': ['working',
#   'a',
#   'oratory,',
#   'genetic,',
#   'also',
#   'genetic,',
#   'completely',
#   'learn',
#   'to',
#   'that?',
#   'growing',
#   'a',
#   'a',
#   'a'],
#  'working': ['out'],
#  'out': ['so', 'that', 'the', 'of', 'every'],
#  'so': ['far?',
#   'I',
#   'apparent–',
#   'he',
#   'he',
#   'when',
#   'forth.’',
#   'much',
#   'did',
#   'it’s',
#   'much?',
#   'it’s',
#   'to',
#   'we'],
#  'far?': [''],
#  '': ['GEORGE',
#   'GEORGE:',
#   'JON:',
#   'GEORGE:',
#   'JON:',
#   'GEORGE:',
#   'GEORGE:',
#   'JON:',
#   '\n\n'],
#  'GEORGE': ['CARLIN:'],
#  'CARLIN:': ['Well,'],
#  'Well,': ['I', 'to', 'he', 'that’s', 'that’s', 'I’m', 'that'],
#  'I': ['knew',
#   'wanted',
#   'have,',
#   'was',
#   'think',
#   'thanked',
#   'watch',
#   'never',
#   'never',
#   'was',
#   'began',
#   'went',
#   'grew',
#   'thought',
#   'went',
#   'went',
#   'lived',
#   'mean,',
#   'don’t',
#   'think',
#   'think',
#   'have',
#   'don’t',
#   'do,',
#   'hardly',
#   'write',
#   'write',
#   'really',
#   'need',
#   'find',
#   'can',
#   'have',
#   'would',
#   'meet',
#   'think,',
#   'go',
#   'come',
#   'love',
#   'hate',
#   'hate',
#   'dislike',
#   'love',
#   'have',
#   'never',
#   'say,',
#   'saw',
#   'said,',
#   'guess',
#   'guess',
#   'cute?’',
#   'got,',
#   'got',
#   'got',
#   'wanted.',
#   'got',
#   'just',
#   'can’t',
#   'look'],
#  'knew': ['I', 'him'],
#  'stand': ['up,'],
#  'know,': ['I’d',
#   'when',
#   'my',
#   'as',
#   'the',
#   'you',
#   'of',
#   'there',
#   'it’s',
#   'JON:',
#   'because',
#   'hey,',
#   'longevity',
#   'when'],
#  'I’d': ['be'],
#  'silly': ['and'],
#  'have': ['people',
#   'a',
#   'grades,',
#   'any',
#   'luck',
#   'to',
#   'something',
#   'a',
#   'to',
#   'to',
#   'always',
#   'to',
#   'wonderful',
#   'little',
#   'gotten',
#   'grades,',
#   'A’s',
#   'mine,'],
#  'people': ['say,',
#   'go',
#   'who',
#   'around',
#   'don’t',
#   'are.',
#   'who',
#   'with',
#   'they’re',
#   'who'],
#  'say,': ['‘Ain’t',
#   '‘Oh,',
#   '‘Oh,',
#   'when',
#   'I’m',
#   'extended',
#   '‘Georgie’s',
#   '‘Well,',
#   '‘Isn’t'],
#  '‘Ain’t': ['you'],
#  'cute?': ['Ain’t', 'He’s'],
#  'Ain’t': ['you'],
#  'cute': ['and'],
#  'clever?’': ['And'],
#  'And': ['that’s',
#   'I',
#   'with',
#   'to',
#   'he,',
#   'so',
#   'the',
#   'one',
#   'you’ve',
#   'another',
#   'as',
#   'you',
#   'willing',
#   'they',
#   'if',
#   'so,',
#   'I',
#   'so,',
#   'if',
#   'those',
#   'I',
#   'you'],
#  'that’s': ['all',
#   'on',
#   'similarly',
#   'luck,',
#   'all',
#   'been',
#   'excellent.',
#   'the'],
#  'all': ['it',
#   'the',
#   'that.',
#   'genetic',
#   'these',
#   'pain,',
#   'these',
#   'I',
#   'boil',
#   'the'],
#  'it': ['was,',
#   'off',
#   'gave',
#   'a',
#   'was',
#   'was',
#   'was',
#   'for',
#   'for',
#   'because',
#   'back',
#   'is',
#   'seems',
#   'is,',
#   'out.',
#   'is,',
#   'drives',
#   'keeps',
#   'is,',
#   'beforehand,',
#   'still',
#   'doesn’t',
#   'all',
#   'just'],
#  'was,': ['is'],
#  'reward,': ['a', 'you'],
#  'psychic': ['reward,'],
#  'when': ['you’re',
#   'you',
#   'I',
#   'I',
#   'I',
#   'you',
#   'I’m',
#   'you',
#   'you',
#   'you’re'],
#  'you’re': ['a',
#   'talking.',
#   'always',
#   'the',
#   'an',
#   'in',
#   'really',
#   'their',
#   'not',
#   'cute.’'],
#  'find': ['out', 'with', 'there’s'],
#  'can': ['get', 'be', 'help', 'do', 'still', 'I', 'see', 'get', 'get'],
#  'get': ['the', 'this', 'rid', 'drunk,', 'applause', 'them', 'the'],
#  'attention': ['of'],
#  'adults': ['and'],
#  'approval': ['and'],
#  'little': ['bit', 'toolkit,', 'pain,', 'more,', 'hats', 'corny,'],
#  'bit': ['of', 'of', 'of'],
#  'respect,': ['and'],
#  'just': ['hung',
#   'comedy,',
#   'natural.',
#   'the',
#   'very,',
#   'doing',
#   'genetic',
#   'that,',
#   'being',
#   'for',
#   'great.',
#   'involves.',
#   'a',
#   'want'],
#  'hung': ['for'],
#  'for': ['it,',
#   'it.',
#   'emphasis',
#   'you,',
#   'rhythms,',
#   'ways',
#   'them',
#   'other',
#   'that,',
#   'all',
#   'no',
#   'a',
#   'you.',
#   'me.',
#   'that.',
#   'you',
#   'not',
#   'me',
#   'all',
#   'dialogue'],
#  'it,': ['you', 'maybe', 'and', 'you', 'it'],
#  'keep': ['going', 'using', 'you'],
#  'going': ['back', 'to', 'somewhere.', 'and', 'to', 'to'],
#  'back': ['for', 'in.'],
#  'it.': ['And', 'That', 'But', 'JON:'],
#  'have,': ['fortunately,'],
#  'fortunately,': ['genetic,'],
#  'genetic,': ['you', 'and', 'the'],
#  'my': ['little',
#   'genetic',
#   'grandmother’s',
#   'mother',
#   'father',
#   'brother',
#   'life,',
#   'house…'],
#  'toolkit,': ['my', 'I'],
#  'genetic': ['toolkit,', 'makeup,', 'because', 'too.', '—'],
#  'given,': ['included'],
#  'included': ['a'],
#  'mother': ['and', 'cared', 'was', 'was'],
#  'father': ['who', 'was'],
#  'very': ['funny',
#   'brave,',
#   'kind',
#   'opposed',
#   'wonderful',
#   'little',
#   'much',
#   'much,'],
#  'funny': ['people,', 'stories'],
#  'people,': ['could', 'believe', 'but'],
#  'could': ['do', 'go', 'do', 'open', 'go', 'go', 'go', 'get', 'go', 'feel'],
#  'accents': ['and'],
#  'dialects': ['and'],
#  'tell': ['funny', 'you'],
#  'stories': ['about'],
#  'what': ['happened', 'we', 'he', 'you', 'you', 'you', 'a'],
#  'happened': ['on'],
#  'bus': ['that', 'rides'],
#  'morning': ['and', 'shows'],
#  'punch': ['line.'],
#  'line.': ['So,'],
#  'don’t': ['lick',
#   'forget',
#   'understand,',
#   'you',
#   'know,',
#   'have',
#   'kid,',
#   'let',
#   'know'],
#  'lick': ['it'],
#  'off': ['the', 'by', 'the'],
#  'rocks,': ['they'],
#  'they': ['say',
#   'would',
#   'died',
#   'do',
#   'will',
#   'buy',
#   'really',
#   'do',
#   'like',
#   'do,',
#   'applaud',
#   'have'],
#  'say': ['in', 'to', 'that,'],
#  'Ireland,': ['so'],
#  'thanked': ['my'],
#  'grandmother’s': ['milkman,'],
#  'milkman,': ['actually,'],
#  'actually,': ['you'],
#  'never': ['know', 'knew,', 'knew', 'had', 'had,'],
#  'know': ['where', 'where', 'what', 'you'],
#  'where': ['these', 'you', 'it', 'the'],
#  'these': ['things…', 'things', 'millennia', 'great', 'people,'],
#  'things…': ['JON:'],
#  'JON:': ['It’s',
#   'That’s',
#   'Were',
#   'People',
#   'Are',
#   'Well,',
#   'More',
#   'And',
#   'Picasso',
#   'Do',
#   'Yeah.',
#   'So',
#   'Thank'],
#  'It’s': ['interesting,', 'this', 'three', 'just'],
#  'interesting,': ['you'],
#  'watch': ['now'],
#  'now': ['and'],
#  'years': ['of'],
#  'listening': ['to'],
#  'your': ['abs',
#   'fascination',
#   'work,',
#   'parents',
#   'genetic',
#   'life',
#   'month',
#   'place'],
#  'abs': ['of'],
#  'things,': ['your'],
#  'fascination': ['with', 'for'],
#  'language,': ['it’s', 'my', 'Sister,'],
#  'it’s': ['so',
#   'almost',
#   'rhetoric,',
#   'not',
#   'a',
#   'just',
#   'the',
#   'kind',
#   'just,',
#   'not',
#   'not',
#   'just',
#   'almost',
#   'like',
#   'all',
#   'punch-up',
#   'special',
#   'a',
#   'okay.’',
#   'about,'],
#  'apparent–': ['watching'],
#  'watching': ['your', 'a'],
#  'work,': ['it’s', 'the'],
#  'almost': ['like', 'all'],
#  'like': ['watching', 'that,', 'part', 'all', 'with', 'you,', 'you’re'],
#  'musician,': ['you'],
#  'way': ['you', 'I'],
#  'weave': ['words'],
#  'words': ['and'],
#  'use': ['language', 'don’t'],
#  'language': ['for', 'and'],
#  'emphasis': ['and'],
#  'that.': ['Was', 'JON:', 'JON:', '“Wonderful,'],
#  'Was': ['that', 'it'],
#  'always': ['a', 'behavior,', 'a', 'gonna'],
#  'you,': ['even', 'and', 'I’m', 'they'],
#  'even': ['as'],
#  'kid?': [''],
#  'GEORGE:': ['Well,',
#   'Yeah,',
#   'Well,',
#   'And',
#   'Well,',
#   'What?',
#   'Well,',
#   'That’s',
#   'Right,',
#   'Well,',
#   '‘Hey,',
#   'And'],
#  'go': ['backward',
#   'counterculture?',
#   'off',
#   'back,',
#   'and',
#   'where',
#   'to',
#   'gambling,',
#   'hooker',
#   'to',
#   'see',
#   'out'],
#  'backward': ['with'],
#  'question,': ['don’t'],
#  'forget': ['what'],
#  'we': ['do',
#   'lived',
#   'saw',
#   'lose',
#   'use',
#   'could',
#   'could',
#   'could',
#   'could',
#   'didn’t',
#   'didn’t'],
#  'oratory,': ['it’s'],
#  'rhetoric,': ['it’s', 'you'],
#  'comedy,': ['it’s'],
#  'form': ['of'],
#  'rhetoric.': ['And'],
#  'look': ['and', 'for', 'forward', 'at,', 'at', 'forward'],
#  'listen': ['for'],
#  'rhythms,': ['you'],
#  'ways': ['to'],
#  'sing': ['at'],
#  'at': ['the', 'the', 'first,', 'first.', 'a', '3:00', 'me,', 'school,'],
#  'same': ['time', 'street', 'block'],
#  'time': ['you’re', 'first.', 'with', 'with'],
#  'talking.': ['And'],
#  'go,': ['‘doom,'],
#  '‘doom,': ['doo'],
#  'doo': ['doo', 'doo', 'doo', 'doo', 'doo', 'doo', 'doo', 'doo', 'doo…,’'],
#  'doo…,’': ['and'],
#  'natural.': ['My'],
#  'My': ['grandfather,', 'mother', 'mother'],
#  'whom': ['I'],
#  'knew,': ['was'],
#  'policeman': ['in'],
#  'New': ['York'],
#  'York': ['at'],
#  'turn': ['of'],
#  'century,': ['and'],
#  'he': ['was',
#   'wrote',
#   'won',
#   'was',
#   'was',
#   'was',
#   'was',
#   'couldn’t',
#   'was',
#   'was',
#   'says',
#   'does,',
#   'around?',
#   'cute?'],
#  'uneducated': ['man,'],
#  'man,': ['self-educated.'],
#  'self-educated.': ['And'],
#  'he,': ['in'],
#  'course': ['of'],
#  'adult': ['life,'],
#  'life,': ['he', 'and'],
#  'wrote': ['out'],
#  'works': ['of'],
#  'Shakespeare': ['by'],
#  'hand': ['because'],
#  'because': ['of', 'the', 'hard', 'the', 'I’ve', 'pretty'],
#  'joy': ['it'],
#  'gave': ['him.'],
#  'him.': [''],
#  'That’s': ['an', 'the', 'it,'],
#  'obsessive': ['young'],
#  'man.': [''],
#  'Yeah,': ['and'],
#  'most': ['everything', 'of', 'of', 'bizarre,'],
#  'everything': ['is'],
#  'cared': ['a'],
#  'lot': ['about', 'of', 'of', 'to', 'of', 'of', 'of'],
#  'champion': ['public'],
#  'public': ['speaker', 'speakers'],
#  'speaker': ['of'],
#  '1935,': ['he'],
#  'won': ['the'],
#  'mahogany': ['gavel,'],
#  'gavel,': ['over'],
#  '800': ['other'],
#  'other': ['public', 'purposes,', 'way,'],
#  'speakers': ['from'],
#  'Dale': ['Carnegie'],
#  'Carnegie': ['Public'],
#  'Public': ['Speaking'],
#  'Speaking': ['Institute,'],
#  'Institute,': ['and'],
#  'great.': ['I', 'It', 'And', 'And', 'And'],
#  'either.': [''],
#  'Were': ['your'],
#  'parents': ['put'],
#  'put': ['off', 'those', 'up'],
#  'direction': ['that', 'at'],
#  'went': ['into', 'in', 'to', 'to'],
#  'started': ['to'],
#  'counterculture?': ['Was'],
#  'difficult': ['transition'],
#  'transition': ['for'],
#  'them': ['to', 'said', 'and', 'alone.', 'to'],
#  'watch?': [''],
#  'picture,': ['he'],
#  'brilliant,': ['and'],
#  'top': ['salesman'],
#  'salesman': ['in'],
#  'advertising,': ['but'],
#  'but': ['he',
#   'some',
#   'it’s',
#   '—',
#   'it’s',
#   'I',
#   'you',
#   'there’s',
#   'they’re',
#   'it',
#   'I’m,',
#   'I',
#   'say,'],
#  'couldn’t': ['metabolize'],
#  'metabolize': ['ethanol'],
#  'ethanol': ['efficiently,'],
#  'efficiently,': ['so'],
#  'given': ['his'],
#  'hat.': ['My'],
#  'brave,': ['she'],
#  'she': ['left', 'was', 'would', 'would', 'said,', 'was'],
#  'left': ['him', 'down'],
#  '2': ['months'],
#  'months': ['old,'],
#  'old,': ['my'],
#  'brother': ['was'],
#  '5': ['years.'],
#  'years.': ['She'],
#  'She': ['left', 'was'],
#  'down': ['a', 'to', 'after', 'to'],
#  'fire': ['escape,'],
#  'escape,': ['so'],
#  'gone.': ['My'],
#  'kind': ['of', 'of'],
#  'controlling,': ['wanted'],
#  'control': ['my'],
#  'heartbroken': ['when'],
#  'began': ['with'],
#  'dirty': ['language'],
#  'awful': ['stuff', 'language,', 'language.’'],
#  'stuff': ['he'],
#  'says': ['about'],
#  'business.': ['She'],
#  'bit,': ['she'],
#  'secretary,': ['loved'],
#  'loved': ['the'],
#  'business': ['world,'],
#  'thought': ['it', 'I'],
#  'finest': ['thing'],
#  'ever': ['happened.', 'any'],
#  'happened.': ['And'],
#  'first,': ['very'],
#  'opposed': ['until'],
#  'until': ['one', 'the'],
#  'one': ['day–', 'of', 'hit,', 'hit,'],
#  'day–': ['we'],
#  'lived': ['in', 'on,'],
#  'street': ['that'],
#  'grew': ['up.'],
#  'up.': ['I'],
#  'school,': ['and', 'and', 'it', 'we'],
#  'block': ['I'],
#  'on,': ['something', 'she'],
#  'something': ['like', 'to', 'to'],
#  'that,': ['Corpus', 'it’s', 'I', 'you', 'I'],
#  'Corpus': ['Christi'],
#  'Christi': ['school,'],
#  'nuns': ['were', 'in'],
#  'It': ['wasn’t', 'can'],
#  'wasn’t': ['a'],
#  'Catholic': ['school,'],
#  'progressive': ['school'],
#  'didn’t': ['have', 'have', 'have', 'have'],
#  'grades,': ['didn’t', 'so'],
#  'any': ['sort', 'pleasure.', 'fear', 'of'],
#  'sort': ['of', 'of', 'of', 'of'],
#  'very,': ['very'],
#  'wonderful': ['school.', 'when', 'thing.', 'people.'],
#  'school.': ['And'],
#  'nuns,': ['she'],
#  'would': ['see', 'say,', 'say,', 'hope,', 'be', 'mention,', 'said'],
#  'see': ['the', 'you', 'this', 'the'],
#  'street,': ['they'],
#  '‘Oh,': ['we', 'it’s', 'well,', 'oh,'],
#  'saw': ['George', 'you,’'],
#  'Tonight': ['Show,’'],
#  'Show,’': ['and'],
#  'she,': ['being'],
#  'being': ['a', 'able', 'wacky,', 'plain', 'dead'],
#  'actress,': ['she'],
#  'Sister,': ['the'],
#  'language.’': ['And'],
#  'said': ['to', 'originally'],
#  'her,': ['‘No,'],
#  '‘No,': ['no,'],
#  'no,': ['you', 'let’s'],
#  'understand,': ['he’s'],
#  'he’s': ['using', 'not'],
#  'using': ['it', 'whatever'],
#  'purposes,': ['he’s'],
#  'doing': ['it'],
#  'part': ['of', 'of', 'decreases,', 'of'],
#  'does,': ['don’t', 'thank'],
#  'understand?': ['It’s'],
#  'forth.’': ['So'],
#  'So': ['she', 'you’re', 'without', 'I', 'it’s,', 'you'],
#  'said,': ['‘Oh,', 'not', '‘Did'],
#  'well,': ['oh,’', 'we'],
#  'oh,’': ['and'],
#  'day': ['on,'],
#  'okay': ['with'],
#  'church': ['had'],
#  'had': ['approved', 'so', 'a', 'to'],
#  'approved': ['it.'],
#  'That': ['was', 'the'],
#  'People': ['who', 'have'],
#  'deal': ['in'],
#  'content': ['that’s'],
#  'edges,': ['you'],
#  'oftentimes': ['live'],
#  'live': ['a', 'for.', 'for,'],
#  'similarly': ['on'],
#  'edge,': ['and'],
#  'those': ['people', 'brushes', 'are'],
#  'rails,': ['and'],
#  'lose': ['them', 'a'],
#  'their': ['talent.',
#   'faces',
#   'eyes,',
#   'cousin,',
#   'attention.',
#   'approval,',
#   'admiration,',
#   'approbation,',
#   'applause.',
#   'enduring'],
#  'talent.': ['And'],
#  'you’ve': ['been', 'done'],
#  'been': ['able', 'a', 'spending', 'for'],
#  'able': ['to', 'to'],
#  'pull': ['it'],
#  'another': ['luck'],
#  'luck': ['stroke,', 'in', 'and'],
#  'stroke,': ['you'],
#  'gotta': ['have'],
#  'its': ['your'],
#  'makeup,': ['that’s'],
#  'luck,': ['and'],
#  'then': ['what', 'some'],
#  'partly': ['genetic'],
#  'hard': ['work', 'work,', 'and'],
#  'work': ['is', 'hard', 'anymore.'],
#  'desire': ['to'],
#  'willingness': ['to'],
#  'determined': ['and'],
#  'turned': ['aside,'],
#  'aside,': ['that’s'],
#  'too.': ['It'],
#  'altered': ['a'],
#  'little,': ['reinforced,'],
#  'reinforced,': ['but'],
#  'some': ['of', 'value', 'pinball.', 'things', 'time'],
#  'edgy': ['promise,'],
#  'promise,': ['they'],
#  'died': ['young.'],
#  'young.': ['I'],
#  'mean,': ['Lenny'],
#  'Lenny': ['Bruce,'],
#  'Bruce,': ['Sam'],
#  'Sam': ['Kinison,'],
#  'Kinison,': ['Andy'],
#  'Andy': ['Kaufman'],
#  'Kaufman': ['in'],
#  'way,': ['Freddie', 'and', 'this,'],
#  'Freddie': ['Prinze,'],
#  'Prinze,': ['John'],
#  'John': ['Belushi,'],
#  'Belushi,': ['Bill'],
#  'Bill': ['Hicks,', 'had'],
#  'Hicks,': ['and'],
#  'just,': ['I'],
#  'course,': ['Bill'],
#  'natural': ['disorder'],
#  'disorder': ['of'],
#  'own,': ['I'],
#  'did': ['Andy,'],
#  'Andy,': ['but'],
#  'behavior,': ['but'],
#  '—': ['so', 'but'],
#  'there’s': ['a', 'hardly', 'a', 'some', 'art'],
#  'degree': ['of'],
#  'intellect': ['involved', 'says,'],
#  'involved': ['in', 'here,', 'here,'],
#  'giving': ['up', 'up', 'up'],
#  'up': ['things', 'the', 'the', 'with'],
#  'things': ['that', 'are', 'we', 'there'],
#  'hurt': ['you.'],
#  'you.': ['That', 'They'],
#  'drug': ['and', 'user'],
#  'alcohol': ['thing,'],
#  'thing,': ['it'],
#  'seems': ['to'],
#  'me,': ['comes', 'but', 'I', 'ain’t'],
#  'comes': ['down', 'from'],
#  'this:': ['drugs'],
#  'are': ['wonderful,',
#   'a',
#   'concerned,',
#   'you',
#   'great.',
#   'the',
#   'gonna',
#   'marked'],
#  'wonderful,': ['they’re'],
#  'they’re': ['wonderful', 'sort', 'not', 'going', 'great.'],
#  'first.': ['They’re', 'The'],
#  'They’re': ['not'],
#  'around': ['for', 'you', 'thinking'],
#  'millennia': ['for'],
#  'no': ['reason.'],
#  'reason.': ['First'],
#  'First': ['time,'],
#  'time,': ['mostly', 'that', 'and'],
#  'mostly': ['pleasure,'],
#  'pleasure,': ['very'],
#  'pain,': ['maybe', 'and'],
#  'maybe': ['a', 'once'],
#  'hangover.': ['And'],
#  'increase': ['and'],
#  'whatever': ['it'],
#  'is,': ['the', 'and', 'and'],
#  'pleasure': ['part', 'this'],
#  'decreases,': ['and'],
#  'pain': ['part,'],
#  'part,': ['the'],
#  'price': ['you'],
#  'pay,': ['increases'],
#  'increases': ['until'],
#  'balance': ['is'],
#  'completely': ['the'],
#  'hardly': ['any', 'touch'],
#  'pleasure.': ['At'],
#  'At': ['that'],
#  'point,': ['you'],
#  'hope,': ['that'],
#  'says,': ['‘Oh,'],
#  'oh,': ['this', 'and'],
#  'doesn’t': ['work', 'boil'],
#  'anymore.': ['I’m'],
#  'I’m': ['going',
#   'sure',
#   'not',
#   'writing',
#   'not',
#   'an',
#   'gonna',
#   'going',
#   'getting',
#   'in',
#   'in'],
#  'die,': ['and'],
#  'I’ll': ['dosomething.’'],
#  'dosomething.’': ['But'],
#  'But': ['you', 'when', 'most'],
#  'need': ['people', 'something', 'now,'],
#  'help': ['you,'],
#  'for.': ['You'],
#  'You': ['have', 'know,', 'can'],
#  'forward': ['to–', 'to'],
#  'to–': ['to'],
#  'bring': ['you'],
#  'out.': ['You', 'The'],
#  'there': ['are', 'ever', 'and', 'that'],
#  'for,': ['and'],
#  'stuck': ['inside.'],
#  'inside.': [''],
#  'Are': ['there'],
#  'fear': ['that'],
#  'drugs,': ['you'],
#  'genius': ['by'],
#  'wild': ['lifestyle?'],
#  'lifestyle?': ['Sanity,'],
#  'Sanity,': ['being…'],
#  'being…': ['GEORGE:'],
#  'canard': ['for'],
#  'long': ['time,'],
#  'creativity': ['comes'],
#  'wacky,': ['and'],
#  'sure': ['there’s'],
#  'truth': ['in'],
#  'far': ['as'],
#  'plain': ['old'],
#  'old': ['wacky.'],
#  'wacky.': ['Where'],
#  'Where': ['the'],
#  'concerned,': ['and'],
#  'alcohol,': ['they'],
#  'seem': ['to', 'to'],
#  'open': ['a', 'up,'],
#  'window': ['for'],
#  'They': ['do', 'don’t,', 'will'],
#  'broaden': ['the'],
#  'vistas': ['at'],
#  'learn': ['when,'],
#  'when,': ['you'],
#  'great': ['writers'],
#  'writers': ['who'],
#  'became': ['drinkers,'],
#  'drinkers,': ['you'],
#  'let,': ['like'],
#  'pot,': ['I’m'],
#  'big': ['drug', 'family,'],
#  'user': ['anymore,'],
#  'anymore,': ['but'],
#  'joint': ['somewhere'],
#  'somewhere': ['near'],
#  'near': ['me.'],
#  'me.': ['I', 'But'],
#  'kid,': ['might'],
#  'might': ['be'],
#  'hidden.': ['What'],
#  'What': ['I'],
#  'do,': ['and', 'but'],
#  'touch': ['it,', 'and'],
#  'once': ['a'],
#  'month,': ['that'],
#  'frequent': ['for'],
#  'writing': ['something,'],
#  'something,': ['and'],
#  'write': ['perfectly', 'a'],
#  'perfectly': ['straight,', 'sober,'],
#  'straight,': ['perfectly'],
#  'sober,': ['I'],
#  'whole': ['lot', 'evening.'],
#  'stuff,': ['six,'],
#  'six,': ['seven,'],
#  'seven,': ['eight,'],
#  'eight,': ['nine'],
#  'nine': ['pages.'],
#  'pages.': ['I'],
#  'really': ['pour', 'wait', 'looking,'],
#  'pour': ['it'],
#  'next': ['day,'],
#  'day,': ['one'],
#  'hit,': ['it’s', 'and'],
#  'now,': ['one'],
#  'punch-up': ['time.'],
#  'time.': ['Time'],
#  'Time': ['to'],
#  'going.': ['And'],
#  'judicious': ['use,'],
#  'use,': ['I'],
#  'value': ['in'],
#  'let': ['you'],
#  'leave': ['them'],
#  'alone.': ['They'],
#  'don’t,': ['pot'],
#  'pot': ['does,'],
#  'thank': ['goodness', 'you'],
#  'goodness': ['for'],
#  'excellent.': ['GEORGE:'],
#  'What?': ['JON:'],
#  'More': ['than'],
#  'fair…': ['Why'],
#  'Why': ['do', 'do', 'do'],
#  'still': ['care?', 'care', 'care', 'works.', 'do'],
#  'care?': ['Why'],
#  'care': ['enough', 'so'],
#  'enough': ['to', 'what'],
#  'back,': ['you'],
#  'month': ['in'],
#  'Vegas,': ['and', 'you’re'],
#  'Florence': ['Henderson'],
#  'Henderson': ['could'],
#  'hit': ['a'],
#  'couple': ['of'],
#  'balls': ['and'],
#  'pinball.': ['Why'],
#  'much?': ['GEORGE:'],
#  'comparing': ['myself'],
#  'myself': ['to'],
#  'believe': ['me,'],
#  'wouldn’t': ['say'],
#  'Picasso,': ['‘When'],
#  '‘When': ['are'],
#  'gonna': ['put', 'be', 'do', 'show'],
#  'brushes': ['down,'],
#  'down,': ['get'],
#  'rid': ['of'],
#  'canvas,': ['you’ve'],
#  'done': ['it?’'],
#  'it?’': ['Not'],
#  'Not': ['you,'],
#  'entertainer': ['first'],
#  'first': ['and'],
#  'foremost,': ['but'],
#  'here,': ['and', 'and'],
#  'artist': ['has'],
#  'has': ['an', 'been'],
#  'obligation': ['to'],
#  'route,': ['to'],
#  'somewhere.': ['There’s'],
#  'There’s': ['a'],
#  'fun.': ['So'],
#  'seeking': ['and'],
#  'looking': ['and'],
#  'trying': ['to', 'to', 'to', 'to'],
#  'challenge': ['yourself.'],
#  'yourself.': ['So'],
#  'without': ['sitting'],
#  'sitting': ['around'],
#  'thinking': ['of'],
#  'lot,': ['it', 'and'],
#  'drives': ['you'],
#  'keeps': ['you'],
#  'fresh,': ['trying'],
#  'new,': ['trying'],
#  'call': ['on', 'showing'],
#  'yourself,': ['calling'],
#  'calling': ['yourself'],
#  'yourself': ['a'],
#  'more,': ['you'],
#  'willing': ['to'],
#  'grueling,': ['promotional'],
#  'promotional': ['schedule'],
#  'schedule': ['and'],
#  'everything.': ['GEORGE:'],
#  'only': ['way.', 'way', 'stop', 'A’s', 'A’s'],
#  'way.': ['JON:'],
#  'Picasso': ['never'],
#  'shows': ['in'],
#  'Albuquerque,': ['you'],
#  'know?': ['GEORGE:', 'JON:', 'I'],
#  'Right,': ['and'],
#  'are.': ['They'],
#  'will': ['not', 'not', 'not'],
#  'come': ['to', 'there', 'home'],
#  'house…': ['[…]'],
#  '[…]': ['bus'],
#  'rides': ['and'],
#  'everything,': ['they'],
#  'come.': ['I'],
#  'Stevens': ['Point,'],
#  'Point,': ['Wisconsin,'],
#  'Wisconsin,': ['or'],
#  'wherever': ['it'],
#  'audiences': ['are'],
#  'buy': ['the'],
#  'tickets': ['ahead'],
#  'ahead': ['of'],
#  'wait': ['for'],
#  'theaters': ['and'],
#  'concert': ['halls'],
#  'halls': ['it’s'],
#  'special': ['because'],
#  'audience,': ['they'],
#  'beforehand,': ['and'],
#  'evening.': ['In'],
#  'Las': ['Vegas,'],
#  'afterthought.': ['You’re'],
#  'You’re': ['an'],
#  'gambling,': ['we'],
#  'hooker': ['in,'],
#  'in,': ['we'],
#  'drunk,': ['we'],
#  'convention,': ['no,'],
#  'let’s': ['go'],
#  'guy.': ['And'],
#  'if': ['they', 'you’re', 'you'],
#  'committed': ['fans,'],
#  'fans,': ['so'],
#  'different': ['tone', 'cities,', 'nights,'],
#  'tone': ['there,'],
#  'there,': ['but', 'their'],
#  'works.': ['You'],
#  'feel': ['good', 'your', 'that,', 'that', 'like'],
#  'good': ['about,'],
#  'about,': ['you', '‘Hey,'],
#  'Do': ['you', 'you', 'you', 'you'],
#  'place': ['in', 'is'],
#  'now?': ['Do'],
#  'I’ve': ['been'],
#  'spending': ['a'],
#  'festival': ['and'],
#  'everybody': ['that'],
#  'mention,': ['you'],
#  'hey,': ['I’m'],
#  'this,': ['George', 'so'],
#  'should': ['be'],
#  'faces': ['light'],
#  'light': ['up,'],
#  'person,': ['“really'],
#  '“really': ['Carlin?,”'],
#  'Carlin?,”': ['and'],
#  'meet': ['him?'],
#  'him?': ['Is'],
#  'Is': ['he'],
#  'around?': ['Do'],
#  'that?': ['GEORGE:'],
#  'think,': ['you'],
#  'longevity': ['is'],
#  'thing.': ['Sometimes'],
#  'Sometimes': ['you'],
#  'applause': ['just'],
#  'dead': ['when'],
#  '60,': ['they'],
#  'applaud': ['that.'],
#  '“Wonderful,': ['not'],
#  'dead,': ['60.”'],
#  '60.”': ['Uh,'],
#  'Uh,': ['so,'],
#  'so,': ['but,', 'cumulatively,', 'cumulatively,'],
#  'but,': ['but'],
#  'I’m,': ['I’m'],
#  'getting': ['a'],
#  'planes': ['three'],
#  'three': ['days', 'different', 'different'],
#  'days': ['a'],
#  'week.': ['I'],
#  'every': ['Friday,', 'Monday.'],
#  'Friday,': ['I'],
#  'home': ['every'],
#  'Monday.': ['It’s'],
#  'cities,': ['three'],
#  'nights,': ['airports,'],
#  'airports,': ['hotel'],
#  'hotel': ['lobbies.'],
#  'lobbies.': ['People'],
#  'people.': ['I', 'I'],
#  'love': ['individuals.', 'individuals.'],
#  'individuals.': ['I', 'Every'],
#  'hate': ['groups', 'people'],
#  'groups': ['of', 'of'],
#  'have–': ['a'],
#  'group': ['of'],
#  'common': ['purpose'],
#  'purpose': ['because'],
#  'pretty': ['soon'],
#  'soon': ['they'],
#  'hats': ['and'],
#  'armbands': ['and'],
#  'fight': ['songs'],
#  'songs': ['and'],
#  'list': ['of'],
#  'visit': ['at'],
#  '3:00': ['a.m.'],
#  'a.m.': ['So'],
#  'dislike': ['and'],
#  'despise': ['groups'],
#  'Every': ['person'],
#  'person': ['you'],
#  'at,': ['you'],
#  'universe': ['in'],
#  'eyes,': ['if'],
#  'looking,': ['and'],
#  'cumulatively,': ['I', 'you'],
#  'gotten': ['the'],
#  'feeling': ['that'],
#  'family,': ['a'],
#  'had,': ['by'],
#  'extended': ['family'],
#  'cousin,': ['you'],
#  '‘Georgie’s': ['1961.'],
#  '1961.': ['I'],
#  'you,’': ['‘Hey,'],
#  '‘Hey,': ['remember,', 'dig', 'look'],
#  'remember,': ['yeah,'],
#  'yeah,': ['oh,'],
#  'said?’': ['And'],
#  '‘Did': ['I?’'],
#  'I?’': ['Oh,'],
#  'Oh,': ['yeah.'],
#  'yeah.': ['So'],
#  'it’s,': ['you’re'],
#  '‘Well,': ['I'],
#  'guess': ['I’m', 'it’s'],
#  'family.': ['I'],
#  'okay.’': ['JON:'],
#  'Yeah.': ['Do'],
#  'boil': ['down', 'down'],
#  'after': ['10', 'a', 'Grammy', 'Emmy', 'Cable'],
#  '10': ['HBO'],
#  'HBO': ['hours,'],
#  'hours,': ['after'],
#  'multitude': ['of'],
#  'best-selling': ['albums,'],
#  'albums,': ['after'],
#  'Grammy': ['nominations,'],
#  'nominations,': ['after', 'after'],
#  'Emmy': ['nominations,'],
#  'Cable': ['ACE'],
#  'ACE': ['Awards?'],
#  'Awards?': ['Does'],
#  'Does': ['it'],
#  'originally': ['that'],
#  'dig': ['me…’'],
#  'me…’': ['GEORGE:'],
#  'ain’t': ['I'],
#  'cute?’': ['That’s'],
#  'involves.': ['It’s'],
#  'dopey': ['call'],
#  'showing': ['off.'],
#  'off.': ['And'],
#  'stop': ['and'],
#  'listen,': ['but'],
#  '‘Isn’t': ['he'],
#  'He’s': ['real–'],
#  'real–': ['you’re'],
#  'cute.’': ['If'],
#  'If': ['you'],
#  'approval–': ['you'],
#  'see,': ['at'],
#  'A’s': ['and', 'I', 'I'],
#  'B’s': ['and'],
#  'C’s': ['and'],
#  'D’s,': ['the'],
#  'got,': ['and'],
#  'corny,': ['I'],
#  'got': ['their', 'their', 'them.'],
#  'attention.': ['I'],
#  'approval,': ['their'],
#  'admiration,': ['their'],
#  'approbation,': ['and'],
#  'applause.': ['And'],
#  'wanted.': ['And'],
#  'them.': ['So…'],
#  'So…': ['JON:'],
#  'mine,': ['sir.'],
#  'sir.': ['I', 'George'],
#  'want': ['to'],
#  'can’t': ['tell'],
#  'me': ['to'],
#  'spend': ['some'],
#  'show,': ['and'],
#  'wonderful–': ['to'],
#  'little.': ['GEORGE:'],
#  'show': ['us'],
#  'us': ['a'],
#  'Thank': ['you'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'See the finest thing that the audiences are concerned, and I never knew I can.'

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
import random

def generate_sentence(chain, count=15):
  """
  Input a dictionary in the format of key = current word, value = list of next words
  along with the number of words you would like to see in your generated sentence.

  This improved version allows for ending with a random punctuation mark or stopping
  at a word with existing punctuation.
  """

  # Capitalize the first word
  word1 = random.choice(list(chain.keys()))
  sentence = word1.capitalize()

  # Generate subsequent words
  for i in range(count - 1):
    word2 = random.choice(chain[word1])

    # Check if word2 already ends with punctuation
    if word2[-1] in ".?!":
      sentence += ' ' + word2
      break  # Stop generating if punctuation is found
    else:
      word1 = word2
      sentence += ' ' + word2

  # Choose a random punctuation mark with some probability (adjust weights as needed)
  if random.random() < 0.7:  # 70% chance of adding punctuation
    punctuation = random.choice([".", "!", "?"])
    sentence += punctuation

  return sentence

# %% [markdown]
# Improvements:
#
# Ending with punctuation:
# We check if the chosen word word2 already ends with a punctuation mark (".?!")
# If it does, the sentence is appended with the word and a break statement exits the loop, ensuring the sentence ends there.
# Random punctuation:
# We introduce a random chance (adjustable by modifying the value < 0.7) to append a random punctuation mark (".", "!", "?") after the sentence is generated.

# %%
generate_sentence(ali_dict, count=15)
# Out:
# 'Talking. And another luck stroke, you know, there that you very wonderful thing.!'
