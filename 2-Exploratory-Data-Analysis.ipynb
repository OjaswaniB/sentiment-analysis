# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# After the data cleaning step where we put our data into a few standard formats, the next step is to take a look at the data and see if what we're looking at makes sense. Before applying any fancy algorithms, it's always important to explore the data first.
#
# When working with numerical data, some of the exploratory data analysis (EDA) techniques we can use include finding the average of the data set, the distribution of the data, the most common values, etc. The idea is the same when working with text data. We are going to find some more obvious patterns with EDA before identifying the hidden patterns with machines learning (ML) techniques. We are going to look at the following for each comedian:
#
# 1. **Most common words** - find these and create word clouds
# 2. **Size of vocabulary** - look number of unique words and also how quickly someone speaks
# 3. **Amount of profanity** - most common terms

# %% [markdown]
# ## Most Common Words

# %% [markdown]
# ### Analysis

# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('dtm.pkl')
data = data.transpose()
data.head()
# Out:
#            david  gabriel  george  jon  kate  kevin  leanne  lewis  louis  \
# aaaaah         0        0       0    0     0      0       0      0      0
# aaaahhh        0        0       0    0     0      0       0      0      1
# aaah           0        1       0    0     0      0       0      0      0
# aah            0        0       0    0     1      0       0      0      4
# abandoned      0        0       0    0     0      0       1      0      0
#
#            matt  pete  roseanne  sammy  shane  stavros
# aaaaah        0     0         0      0      0        1
# aaaahhh       0     0         0      0      0        0
# aaah          0     0         0      0      0        0
# aah           0     1         0      0      0        0
# abandoned     0     0         0      0      0        0

# %%
# Find the top 30 words said by each comedian
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {'david': [('audience', 219),
#   ('like', 170),
#   ('laughing', 159),
#   ('just', 86),
#   ('know', 81),
#   ('irish', 71),
#   ('yeah', 70),
#   ('im', 67),
#   ('thats', 56),
#   ('people', 54),
#   ('youre', 52),
#   ('applauding', 50),
#   ('oh', 48),
#   ('bit', 46),
#   ('said', 44),
#   ('cause', 42),
#   ('dont', 41),
#   ('got', 40),
#   ('didnt', 36),
#   ('america', 33),
#   ('did', 31),
#   ('ireland', 30),
#   ('really', 29),
#   ('time', 28),
#   ('gonna', 28),
#   ('love', 27),
#   ('went', 27),
#   ('little', 27),
#   ('going', 26),
#   ('hes', 24)],
#  'gabriel': [('like', 168),
#   ('im', 153),
#   ('know', 152),
#   ('said', 84),
#   ('just', 72),
#   ('dont', 67),
#   ('youre', 64),
#   ('thats', 60),
#   ('right', 54),
#   ('going', 53),
#   ('got', 51),
#   ('okay', 49),
#   ('oh', 48),
#   ('hes', 46),
#   ('yeah', 46),
#   ('gonna', 45),
#   ('people', 43),
#   ('tell', 38),
#   ('look', 36),
#   ('thank', 35),
#   ('want', 35),
#   ('time', 34),
#   ('cause', 34),
#   ('thing', 33),
#   ('say', 33),
#   ('did', 32),
#   ('little', 31),
#   ('make', 30),
#   ('guys', 29),
#   ('good', 29)],
#  'george': [('people', 62),
#   ('fcking', 42),
#   ('im', 42),
#   ('dont', 42),
#   ('youre', 37),
#   ('just', 36),
#   ('like', 36),
#   ('know', 33),
#   ('going', 32),
#   ('want', 31),
#   ('fck', 29),
#   ('thats', 29),
#   ('got', 28),
#   ('right', 24),
#   ('george', 24),
#   ('think', 23),
#   ('time', 23),
#   ('world', 23),
#   ('really', 23),
#   ('shit', 23),
#   ('years', 22),
#   ('asshole', 22),
#   ('getting', 21),
#   ('make', 20),
#   ('carlin', 20),
#   ('american', 20),
#   ('theyre', 19),
#   ('ai', 19),
#   ('rich', 18),
#   ('everybody', 16)],
#  'jon': [('know', 21),
#   ('george', 18),
#   ('people', 17),
#   ('just', 15),
#   ('jon', 15),
#   ('say', 12),
#   ('im', 12),
#   ('thats', 11),
#   ('youre', 11),
#   ('doo', 10),
#   ('dont', 10),
#   ('time', 9),
#   ('lot', 9),
#   ('life', 9),
#   ('school', 8),
#   ('little', 8),
#   ('genetic', 8),
#   ('carlin', 8),
#   ('oh', 8),
#   ('like', 7),
#   ('wonderful', 7),
#   ('look', 7),
#   ('going', 7),
#   ('theres', 6),
#   ('theyre', 6),
#   ('thing', 6),
#   ('way', 6),
#   ('language', 6),
#   ('things', 6),
#   ('think', 6)],
#  'kate': [('like', 115),
#   ('im', 98),
#   ('know', 86),
#   ('yeah', 68),
#   ('okay', 67),
#   ('right', 67),
#   ('just', 61),
#   ('oh', 49),
#   ('thats', 45),
#   ('dont', 38),
#   ('um', 37),
#   ('actually', 33),
#   ('really', 32),
#   ('want', 28),
#   ('ill', 27),
#   ('say', 27),
#   ('youre', 26),
#   ('feel', 24),
#   ('gonna', 19),
#   ('think', 18),
#   ('good', 17),
#   ('life', 16),
#   ('way', 16),
#   ('kind', 15),
#   ('cause', 15),
#   ('theres', 15),
#   ('uh', 14),
#   ('people', 13),
#   ('tonight', 12),
#   ('time', 12)],
#  'kevin': [('like', 133),
#   ('know', 111),
#   ('just', 91),
#   ('dont', 82),
#   ('im', 80),
#   ('thats', 58),
#   ('right', 38),
#   ('goes', 37),
#   ('youre', 36),
#   ('got', 33),
#   ('time', 32),
#   ('did', 32),
#   ('good', 31),
#   ('hes', 31),
#   ('yeah', 30),
#   ('shes', 28),
#   ('theyre', 26),
#   ('say', 26),
#   ('kids', 24),
#   ('gonna', 24),
#   ('cause', 24),
#   ('gotta', 23),
#   ('going', 21),
#   ('talk', 21),
#   ('little', 20),
#   ('day', 20),
#   ('wanna', 19),
#   ('lets', 19),
#   ('oh', 19),
#   ('hey', 18)],
#  'leanne': [('know', 76),
#   ('yall', 62),
#   ('gonna', 60),
#   ('like', 59),
#   ('im', 57),
#   ('got', 50),
#   ('said', 45),
#   ('dont', 43),
#   ('ive', 39),
#   ('little', 39),
#   ('thank', 34),
#   ('just', 33),
#   ('big', 32),
#   ('right', 31),
#   ('okay', 30),
#   ('hes', 29),
#   ('husband', 29),
#   ('time', 28),
#   ('baby', 28),
#   ('thought', 24),
#   ('thats', 24),
#   ('did', 24),
#   ('people', 24),
#   ('let', 22),
#   ('love', 22),
#   ('say', 21),
#   ('thing', 21),
#   ('remember', 20),
#   ('want', 19),
#   ('going', 19)],
#  'lewis': [('fucking', 75),
#   ('im', 48),
#   ('dont', 43),
#   ('people', 43),
#   ('know', 42),
#   ('gonna', 41),
#   ('really', 40),
#   ('fuck', 38),
#   ('said', 37),
#   ('didnt', 31),
#   ('like', 27),
#   ('got', 26),
#   ('just', 25),
#   ('time', 24),
#   ('youre', 24),
#   ('ok', 23),
#   ('shit', 23),
#   ('thats', 22),
#   ('knew', 21),
#   ('thought', 19),
#   ('going', 19),
#   ('theyre', 18),
#   ('goddammit', 18),
#   ('think', 18),
#   ('did', 18),
#   ('cats', 18),
#   ('oh', 17),
#   ('fucked', 17),
#   ('say', 16),
#   ('right', 16)],
#  'louis': [('like', 152),
#   ('just', 95),
#   ('know', 77),
#   ('dont', 65),
#   ('youre', 56),
#   ('im', 56),
#   ('thats', 50),
#   ('jesus', 49),
#   ('theres', 42),
#   ('fucking', 36),
#   ('cause', 32),
#   ('hes', 32),
#   ('gonna', 32),
#   ('people', 31),
#   ('right', 27),
#   ('got', 27),
#   ('theyre', 26),
#   ('make', 25),
#   ('really', 22),
#   ('life', 22),
#   ('good', 21),
#   ('fuck', 20),
#   ('want', 20),
#   ('okay', 19),
#   ('oh', 19),
#   ('guy', 18),
#   ('think', 18),
#   ('little', 18),
#   ('time', 16),
#   ('look', 16)],
#  'matt': [('like', 174),
#   ('know', 98),
#   ('im', 85),
#   ('just', 79),
#   ('dont', 54),
#   ('thats', 54),
#   ('fucking', 49),
#   ('oh', 46),
#   ('think', 44),
#   ('man', 41),
#   ('want', 41),
#   ('okay', 40),
#   ('people', 39),
#   ('youre', 34),
#   ('good', 33),
#   ('going', 32),
#   ('life', 30),
#   ('fuck', 28),
#   ('hes', 28),
#   ('time', 28),
#   ('god', 27),
#   ('right', 27),
#   ('red', 26),
#   ('shit', 25),
#   ('fun', 23),
#   ('gonna', 22),
#   ('theyre', 22),
#   ('special', 21),
#   ('guys', 21),
#   ('day', 20)],
#  'pete': [('like', 193),
#   ('know', 126),
#   ('im', 84),
#   ('goes', 63),
#   ('dont', 62),
#   ('just', 58),
#   ('thats', 52),
#   ('mom', 42),
#   ('right', 39),
#   ('shes', 39),
#   ('youre', 35),
#   ('yeah', 34),
#   ('fuck', 32),
#   ('cause', 31),
#   ('fucking', 30),
#   ('got', 27),
#   ('okay', 25),
#   ('little', 23),
#   ('going', 23),
#   ('want', 23),
#   ('time', 23),
#   ('good', 22),
#   ('think', 20),
#   ('hes', 20),
#   ('oh', 20),
#   ('hey', 18),
#   ('tell', 18),
#   ('theyre', 17),
#   ('gay', 17),
#   ('said', 17)],
#  'roseanne': [('know', 95),
#   ('im', 90),
#   ('like', 74),
#   ('just', 42),
#   ('youre', 42),
#   ('dont', 35),
#   ('really', 34),
#   ('right', 34),
#   ('theyre', 34),
#   ('thats', 32),
#   ('yeah', 31),
#   ('people', 30),
#   ('going', 29),
#   ('shit', 24),
#   ('good', 24),
#   ('got', 24),
#   ('gonna', 24),
#   ('woman', 22),
#   ('want', 22),
#   ('audience', 20),
#   ('oh', 20),
#   ('kind', 19),
#   ('love', 19),
#   ('say', 18),
#   ('kids', 18),
#   ('mean', 17),
#   ('time', 17),
#   ('didnt', 17),
#   ('said', 17),
#   ('think', 17)],
#  'sammy': [('like', 40),
#   ('im', 24),
#   ('just', 14),
#   ('uh', 13),
#   ('know', 13),
#   ('said', 12),
#   ('thats', 11),
#   ('people', 11),
#   ('dont', 10),
#   ('bethlehem', 10),
#   ('comedy', 10),
#   ('youre', 9),
#   ('buddy', 7),
#   ('trust', 7),
#   ('hes', 7),
#   ('country', 7),
#   ('trying', 6),
#   ('magician', 6),
#   ('israel', 6),
#   ('think', 6),
#   ('political', 6),
#   ('um', 6),
#   ('crowd', 6),
#   ('palestine', 6),
#   ('believe', 5),
#   ('did', 5),
#   ('everybody', 4),
#   ('say', 4),
#   ('oh', 4),
#   ('doing', 4)],
#  'shane': [('like', 231),
#   ('just', 74),
#   ('know', 55),
#   ('thats', 50),
#   ('dont', 38),
#   ('fcking', 37),
#   ('got', 37),
#   ('dude', 36),
#   ('hes', 34),
#   ('guys', 34),
#   ('im', 33),
#   ('good', 28),
#   ('theyre', 27),
#   ('dad', 22),
#   ('fck', 21),
#   ('funny', 20),
#   ('news', 20),
#   ('say', 19),
#   ('theres', 18),
#   ('right', 17),
#   ('yeah', 17),
#   ('think', 16),
#   ('guy', 15),
#   ('white', 14),
#   ('time', 14),
#   ('fox', 14),
#   ('night', 14),
#   ('doing', 14),
#   ('going', 13),
#   ('trump', 13)],
#  'stavros': [('like', 218),
#   ('know', 153),
#   ('im', 111),
#   ('right', 90),
#   ('just', 81),
#   ('yeah', 73),
#   ('thats', 63),
#   ('dont', 42),
#   ('gonna', 41),
#   ('youre', 35),
#   ('got', 31),
#   ('good', 30),
#   ('time', 29),
#   ('mean', 24),
#   ('think', 23),
#   ('little', 23),
#   ('going', 23),
#   ('guy', 23),
#   ('really', 23),
#   ('oh', 23),
#   ('want', 21),
#   ('pretty', 20),
#   ('doing', 20),
#   ('lot', 20),
#   ('fck', 20),
#   ('fcking', 19),
#   ('way', 19),
#   ('nice', 18),
#   ('life', 18),
#   ('sex', 18)]}

# %%
# Print the top 15 words said by each comedian
for comedian, top_words in top_dict.items():
    print(comedian)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('---')
# Out:
# david
# audience, like, laughing, just, know, irish, yeah, im, thats, people, youre, applauding, oh, bit
# ---
# gabriel
# like, im, know, said, just, dont, youre, thats, right, going, got, okay, oh, hes
# ---
# george
# people, fcking, im, dont, youre, just, like, know, going, want, fck, thats, got, right
# ---
# jon
# know, george, people, just, jon, say, im, thats, youre, doo, dont, time, lot, life
# ---
# kate
# like, im, know, yeah, okay, right, just, oh, thats, dont, um, actually, really, want
# ---
# kevin
# like, know, just, dont, im, thats, right, goes, youre, got, time, did, good, hes
# ---
# leanne
# know, yall, gonna, like, im, got, said, dont, ive, little, thank, just, big, right
# ---
# lewis
# fucking, im, dont, people, know, gonna, really, fuck, said, didnt, like, got, just, time
# ---
# louis
# like, just, know, dont, youre, im, thats, jesus, theres, fucking, cause, hes, gonna, people
# ---
# matt
# like, know, im, just, dont, thats, fucking, oh, think, man, want, okay, people, youre
# ---
# pete
# like, know, im, goes, dont, just, thats, mom, right, shes, youre, yeah, fuck, cause
# ---
# roseanne
# know, im, like, just, youre, dont, really, right, theyre, thats, yeah, people, going, shit
# ---
# sammy
# like, im, just, uh, know, said, thats, people, dont, bethlehem, comedy, youre, buddy, trust
# ---
# shane
# like, just, know, thats, dont, fcking, got, dude, hes, guys, im, good, theyre, dad
# ---
# stavros
# like, know, im, right, just, yeah, thats, dont, gonna, youre, got, good, time, mean
# ---

# %% [markdown]
# **NOTE:** At this point, we could go on and create word clouds. However, by looking at these top words, you can see that some of them have very little meaning and could be added to a stop words list, so let's do just that.

# %%
# Look at the most common top words --> add them to the stop word list
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for comedian in data.columns:
    top = [word for (word, count) in top_dict[comedian]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['audience',
#  'like',
#  'laughing',
#  'just',
#  'know',
#  'irish',
#  'yeah',
#  'im',
#  'thats',
#  'people',
#  'youre',
#  'applauding',
#  'oh',
#  'bit',
#  'said',
#  'cause',
#  'dont',
#  'got',
#  'didnt',
#  'america',
#  'did',
#  'ireland',
#  'really',
#  'time',
#  'gonna',
#  'love',
#  'went',
#  'little',
#  'going',
#  'hes',
#  'like',
#  'im',
#  'know',
#  'said',
#  'just',
#  'dont',
#  'youre',
#  'thats',
#  'right',
#  'going',
#  'got',
#  'okay',
#  'oh',
#  'hes',
#  'yeah',
#  'gonna',
#  'people',
#  'tell',
#  'look',
#  'thank',
#  'want',
#  'time',
#  'cause',
#  'thing',
#  'say',
#  'did',
#  'little',
#  'make',
#  'guys',
#  'good',
#  'people',
#  'fcking',
#  'im',
#  'dont',
#  'youre',
#  'just',
#  'like',
#  'know',
#  'going',
#  'want',
#  'fck',
#  'thats',
#  'got',
#  'right',
#  'george',
#  'think',
#  'time',
#  'world',
#  'really',
#  'shit',
#  'years',
#  'asshole',
#  'getting',
#  'make',
#  'carlin',
#  'american',
#  'theyre',
#  'ai',
#  'rich',
#  'everybody',
#  'know',
#  'george',
#  'people',
#  'just',
#  'jon',
#  'say',
#  'im',
#  'thats',
#  'youre',
#  'doo',
#  'dont',
#  'time',
#  'lot',
#  'life',
#  'school',
#  'little',
#  'genetic',
#  'carlin',
#  'oh',
#  'like',
#  'wonderful',
#  'look',
#  'going',
#  'theres',
#  'theyre',
#  'thing',
#  'way',
#  'language',
#  'things',
#  'think',
#  'like',
#  'im',
#  'know',
#  'yeah',
#  'okay',
#  'right',
#  'just',
#  'oh',
#  'thats',
#  'dont',
#  'um',
#  'actually',
#  'really',
#  'want',
#  'ill',
#  'say',
#  'youre',
#  'feel',
#  'gonna',
#  'think',
#  'good',
#  'life',
#  'way',
#  'kind',
#  'cause',
#  'theres',
#  'uh',
#  'people',
#  'tonight',
#  'time',
#  'like',
#  'know',
#  'just',
#  'dont',
#  'im',
#  'thats',
#  'right',
#  'goes',
#  'youre',
#  'got',
#  'time',
#  'did',
#  'good',
#  'hes',
#  'yeah',
#  'shes',
#  'theyre',
#  'say',
#  'kids',
#  'gonna',
#  'cause',
#  'gotta',
#  'going',
#  'talk',
#  'little',
#  'day',
#  'wanna',
#  'lets',
#  'oh',
#  'hey',
#  'know',
#  'yall',
#  'gonna',
#  'like',
#  'im',
#  'got',
#  'said',
#  'dont',
#  'ive',
#  'little',
#  'thank',
#  'just',
#  'big',
#  'right',
#  'okay',
#  'hes',
#  'husband',
#  'time',
#  'baby',
#  'thought',
#  'thats',
#  'did',
#  'people',
#  'let',
#  'love',
#  'say',
#  'thing',
#  'remember',
#  'want',
#  'going',
#  'fucking',
#  'im',
#  'dont',
#  'people',
#  'know',
#  'gonna',
#  'really',
#  'fuck',
#  'said',
#  'didnt',
#  'like',
#  'got',
#  'just',
#  'time',
#  'youre',
#  'ok',
#  'shit',
#  'thats',
#  'knew',
#  'thought',
#  'going',
#  'theyre',
#  'goddammit',
#  'think',
#  'did',
#  'cats',
#  'oh',
#  'fucked',
#  'say',
#  'right',
#  'like',
#  'just',
#  'know',
#  'dont',
#  'youre',
#  'im',
#  'thats',
#  'jesus',
#  'theres',
#  'fucking',
#  'cause',
#  'hes',
#  'gonna',
#  'people',
#  'right',
#  'got',
#  'theyre',
#  'make',
#  'really',
#  'life',
#  'good',
#  'fuck',
#  'want',
#  'okay',
#  'oh',
#  'guy',
#  'think',
#  'little',
#  'time',
#  'look',
#  'like',
#  'know',
#  'im',
#  'just',
#  'dont',
#  'thats',
#  'fucking',
#  'oh',
#  'think',
#  'man',
#  'want',
#  'okay',
#  'people',
#  'youre',
#  'good',
#  'going',
#  'life',
#  'fuck',
#  'hes',
#  'time',
#  'god',
#  'right',
#  'red',
#  'shit',
#  'fun',
#  'gonna',
#  'theyre',
#  'special',
#  'guys',
#  'day',
#  'like',
#  'know',
#  'im',
#  'goes',
#  'dont',
#  'just',
#  'thats',
#  'mom',
#  'right',
#  'shes',
#  'youre',
#  'yeah',
#  'fuck',
#  'cause',
#  'fucking',
#  'got',
#  'okay',
#  'little',
#  'going',
#  'want',
#  'time',
#  'good',
#  'think',
#  'hes',
#  'oh',
#  'hey',
#  'tell',
#  'theyre',
#  'gay',
#  'said',
#  'know',
#  'im',
#  'like',
#  'just',
#  'youre',
#  'dont',
#  'really',
#  'right',
#  'theyre',
#  'thats',
#  'yeah',
#  'people',
#  'going',
#  'shit',
#  'good',
#  'got',
#  'gonna',
#  'woman',
#  'want',
#  'audience',
#  'oh',
#  'kind',
#  'love',
#  'say',
#  'kids',
#  'mean',
#  'time',
#  'didnt',
#  'said',
#  'think',
#  'like',
#  'im',
#  'just',
#  'uh',
#  'know',
#  'said',
#  'thats',
#  'people',
#  'dont',
#  'bethlehem',
#  'comedy',
#  'youre',
#  'buddy',
#  'trust',
#  'hes',
#  'country',
#  'trying',
#  'magician',
#  'israel',
#  'think',
#  'political',
#  'um',
#  'crowd',
#  'palestine',
#  'believe',
#  'did',
#  'everybody',
#  'say',
#  'oh',
#  'doing',
#  'like',
#  'just',
#  'know',
#  'thats',
#  'dont',
#  'fcking',
#  'got',
#  'dude',
#  'hes',
#  'guys',
#  'im',
#  'good',
#  'theyre',
#  'dad',
#  'fck',
#  'funny',
#  'news',
#  'say',
#  'theres',
#  'right',
#  'yeah',
#  'think',
#  'guy',
#  'white',
#  'time',
#  'fox',
#  'night',
#  'doing',
#  'going',
#  'trump',
#  'like',
#  'know',
#  'im',
#  'right',
#  'just',
#  'yeah',
#  'thats',
#  'dont',
#  'gonna',
#  'youre',
#  'got',
#  'good',
#  'time',
#  'mean',
#  'think',
#  'little',
#  'going',
#  'guy',
#  'really',
#  'oh',
#  'want',
#  'pretty',
#  'doing',
#  'lot',
#  'fck',
#  'fcking',
#  'way',
#  'nice',
#  'life',
#  'sex']

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('like', 15),
#  ('just', 15),
#  ('know', 15),
#  ('im', 15),
#  ('thats', 15),
#  ('dont', 15),
#  ('time', 14),
#  ('youre', 13),
#  ('oh', 12),
#  ('going', 12),
#  ('right', 12),
#  ('people', 11),
#  ('got', 11),
#  ('think', 11),
#  ('gonna', 10),
#  ('hes', 9),
#  ('want', 9),
#  ('say', 9),
#  ('good', 9),
#  ('theyre', 9),
#  ('yeah', 8),
#  ('little', 8),
#  ('said', 7),
#  ('really', 7),
#  ('cause', 6),
#  ('did', 6),
#  ('okay', 6),
#  ('life', 5),
#  ('shit', 4),
#  ('theres', 4),
#  ('fucking', 4),
#  ('fuck', 4),
#  ('didnt', 3),
#  ('love', 3),
#  ('look', 3),
#  ('thing', 3),
#  ('make', 3),
#  ('guys', 3),
#  ('fcking', 3),
#  ('fck', 3),
#  ('way', 3),
#  ('guy', 3),
#  ('doing', 3),
#  ('audience', 2),
#  ('tell', 2),
#  ('thank', 2),
#  ('george', 2),
#  ('carlin', 2),
#  ('everybody', 2),
#  ('lot', 2),
#  ('um', 2),
#  ('kind', 2),
#  ('uh', 2),
#  ('goes', 2),
#  ('shes', 2),
#  ('kids', 2),
#  ('day', 2),
#  ('hey', 2),
#  ('thought', 2),
#  ('mean', 2),
#  ('laughing', 1),
#  ('irish', 1),
#  ('applauding', 1),
#  ('bit', 1),
#  ('america', 1),
#  ('ireland', 1),
#  ('went', 1),
#  ('world', 1),
#  ('years', 1),
#  ('asshole', 1),
#  ('getting', 1),
#  ('american', 1),
#  ('ai', 1),
#  ('rich', 1),
#  ('jon', 1),
#  ('doo', 1),
#  ('school', 1),
#  ('genetic', 1),
#  ('wonderful', 1),
#  ('language', 1),
#  ('things', 1),
#  ('actually', 1),
#  ('ill', 1),
#  ('feel', 1),
#  ('tonight', 1),
#  ('gotta', 1),
#  ('talk', 1),
#  ('wanna', 1),
#  ('lets', 1),
#  ('yall', 1),
#  ('ive', 1),
#  ('big', 1),
#  ('husband', 1),
#  ('baby', 1),
#  ('let', 1),
#  ('remember', 1),
#  ('ok', 1),
#  ('knew', 1),
#  ('goddammit', 1),
#  ('cats', 1),
#  ('fucked', 1),
#  ('jesus', 1),
#  ('man', 1),
#  ('god', 1),
#  ('red', 1),
#  ('fun', 1),
#  ('special', 1),
#  ('mom', 1),
#  ('gay', 1),
#  ('woman', 1),
#  ('bethlehem', 1),
#  ('comedy', 1),
#  ('buddy', 1),
#  ('trust', 1),
#  ('country', 1),
#  ('trying', 1),
#  ('magician', 1),
#  ('israel', 1),
#  ('political', 1),
#  ('crowd', 1),
#  ('palestine', 1),
#  ('believe', 1),
#  ('dude', 1),
#  ('dad', 1),
#  ('funny', 1),
#  ('news', 1),
#  ('white', 1),
#  ('fox', 1),
#  ('night', 1),
#  ('trump', 1),
#  ('pretty', 1),
#  ('nice', 1),
#  ('sex', 1)]

# %%
# If more than half of the comedians have it as a top word, exclude it from the list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 6]
add_stop_words
# Out:
# ['like',
#  'just',
#  'know',
#  'im',
#  'thats',
#  'dont',
#  'time',
#  'youre',
#  'oh',
#  'going',
#  'right',
#  'people',
#  'got',
#  'think',
#  'gonna',
#  'hes',
#  'want',
#  'say',
#  'good',
#  'theyre',
#  'yeah',
#  'little',
#  'said',
#  'really']

# %%
# Let's update our document-term matrix with the new list of stop words
from sklearn.feature_extraction import text 
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import pickle

# Read in cleaned data
data_clean = pd.read_pickle('data_clean.pkl')

# Add new stop words
stop_words = list(text.ENGLISH_STOP_WORDS.union(add_stop_words))

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_stop.index = data_clean.index

# Pickle it for later use
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")

# %%
# Let's make some word clouds!
# Terminal / Anaconda Prompt: conda install -c conda-forge wordcloud
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 12]

full_names = [
    'Jon Stewart',
    'Kevin Hart',
    'Pete Davidson',
    'Matt Damon',  
    'David Letterman',
    'Shane Gillis',
    'Lewis Black',
    'Stavros Halkias',
    'George Carlin',
    'Leanne Morgan',
    'Louis C.K.',
    'Roseanne Barr',
    'Sammy Davis Jr.',  
    'Gabriel Iglesias',
    'Kate McKinnon'
]

# Create subplots for each comedian
# Create subplots for each comedian
fig, axes = plt.subplots(4, 4)

for index, comedian in enumerate(data.columns):
    wc.generate(data_clean.transcript[comedian])
    
    ax = axes[index//4, index%4]
    ax.imshow(wc, interpolation="bilinear")
    ax.axis("off")
    ax.set_title(full_names[index])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * Ali Wong says the s-word a lot and talks about her husband. I guess that's funny to me.
# * A lot of people use the F-word. Let's dig into that later.

# %% [markdown]
# ## Number of Words

# %% [markdown]
# ### Analysis

# %%
# Find the number of unique words that each comedian uses

# Identify the non-zero items in the document-term matrix, meaning that the word occurs at least once
unique_list = []
for comedian in data.columns:
    uniques = data[comedian].to_numpy().nonzero()[0].size
    unique_list.append(uniques)

# Create a new dataframe that contains this unique word count
data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['comedian', 'unique_words'])
data_unique_sort = data_words.sort_values(by='unique_words')
data_unique_sort
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       7     unique_list.append(uniques)
#       9 # Create a new dataframe that contains this unique word count
# ---> 10 data_words = pd.DataFrame(list(zip(full_names, unique_list)), columns=['comedian', 'unique_words'])
#      11 data_unique_sort = data_words.sort_values(by='unique_words')
#      12 data_unique_sort
#
# NameError: name 'full_names' is not defined

# %%
# Calculate the words per minute of each comedian

# Find the total number of words that a comedian uses
total_list = []
for comedian in data.columns:
    totals = sum(data[comedian])
    total_list.append(totals)
    
# Comedy special run times from IMDB, in minutes (adjusted to match the number of comedians)
run_times = [60, 59, 80, 60, 67, 73, 77, 63, 62, 58, 76, 79, 80, 83, 88]

# Let's add some columns to our dataframe
data_words['total_words'] = total_list
data_words['run_times'] = run_times[:len(data_words)]  # Adjusted to match the number of comedians
data_words['words_per_minute'] = data_words['total_words'] / data_words['run_times']

# Sort the dataframe by words per minute to see who talks the slowest and fastest
data_wpm_sort = data_words.sort_values(by='words_per_minute')
data_wpm_sort
# Out:
#             comedian  unique_words  total_words  run_times  words_per_minute
# 12   Sammy Davis Jr.           410          796         80          9.950000
# 3         Matt Damon           641         1143         60         19.050000
# 13  Gabriel Iglesias          1062         3132         83         37.734940
# 4    David Letterman          1084         2916         67         43.522388
# 14     Kate McKinnon          1433         4181         88         47.511364
# 11     Roseanne Barr          1382         3803         79         48.139241
# 10        Louis C.K.          1228         3868         76         50.894737
# 7    Stavros Halkias          1164         3265         63         51.825397
# 6        Lewis Black          1355         4032         77         52.363636
# 5       Shane Gillis          1372         4109         73         56.287671
# 2      Pete Davidson          1848         4514         80         56.425000
# 8      George Carlin          1048         3500         62         56.451613
# 9      Leanne Morgan          1365         4436         58         76.482759
# 0        Jon Stewart          1948         6288         60        104.800000
# 1         Kevin Hart          1895         6833         59        115.813559

# %%
# Let's plot our findings
import numpy as np

y_pos = np.arange(len(data_words))

plt.subplot(1, 2, 1)
plt.barh(y_pos, data_unique_sort.unique_words, align='center')
plt.yticks(y_pos, data_unique_sort.comedian)
plt.title('Number of Unique Words', fontsize=20)

plt.subplot(1, 2, 2)
plt.barh(y_pos, data_wpm_sort.words_per_minute, align='center')
plt.yticks(y_pos, data_wpm_sort.comedian)
plt.title('Number of Words Per Minute', fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Vocabulary**
#    * Ricky Gervais (British comedy) and Bill Burr (podcast host) use a lot of words in their comedy
#    * Louis C.K. (self-depricating comedy) and Anthony Jeselnik (dark humor) have a smaller vocabulary
#
#
# * **Talking Speed**
#    * Joe Rogan (blue comedy) and Bill Burr (podcast host) talk fast
#    * Bo Burnham (musical comedy) and Anthony Jeselnik (dark humor) talk slow
#
# Ali Wong is somewhere in the middle in both cases. Nothing too interesting here.

# %% [markdown]
# ## Amount of Profanity

# %% [markdown]
# ### Analysis

# %%
# Earlier I said we'd revisit profanity. Let's take a look at the most common words again.
Counter(words).most_common()
# Out:
# [('like', 15),
#  ('just', 15),
#  ('know', 15),
#  ('im', 15),
#  ('thats', 15),
#  ('dont', 15),
#  ('time', 14),
#  ('youre', 13),
#  ('oh', 12),
#  ('going', 12),
#  ('right', 12),
#  ('people', 11),
#  ('got', 11),
#  ('think', 11),
#  ('gonna', 10),
#  ('hes', 9),
#  ('want', 9),
#  ('say', 9),
#  ('good', 9),
#  ('theyre', 9),
#  ('yeah', 8),
#  ('little', 8),
#  ('said', 7),
#  ('really', 7),
#  ('cause', 6),
#  ('did', 6),
#  ('okay', 6),
#  ('life', 5),
#  ('shit', 4),
#  ('theres', 4),
#  ('fucking', 4),
#  ('fuck', 4),
#  ('didnt', 3),
#  ('love', 3),
#  ('look', 3),
#  ('thing', 3),
#  ('make', 3),
#  ('guys', 3),
#  ('fcking', 3),
#  ('fck', 3),
#  ('way', 3),
#  ('guy', 3),
#  ('doing', 3),
#  ('audience', 2),
#  ('tell', 2),
#  ('thank', 2),
#  ('george', 2),
#  ('carlin', 2),
#  ('everybody', 2),
#  ('lot', 2),
#  ('um', 2),
#  ('kind', 2),
#  ('uh', 2),
#  ('goes', 2),
#  ('shes', 2),
#  ('kids', 2),
#  ('day', 2),
#  ('hey', 2),
#  ('thought', 2),
#  ('mean', 2),
#  ('laughing', 1),
#  ('irish', 1),
#  ('applauding', 1),
#  ('bit', 1),
#  ('america', 1),
#  ('ireland', 1),
#  ('went', 1),
#  ('world', 1),
#  ('years', 1),
#  ('asshole', 1),
#  ('getting', 1),
#  ('american', 1),
#  ('ai', 1),
#  ('rich', 1),
#  ('jon', 1),
#  ('doo', 1),
#  ('school', 1),
#  ('genetic', 1),
#  ('wonderful', 1),
#  ('language', 1),
#  ('things', 1),
#  ('actually', 1),
#  ('ill', 1),
#  ('feel', 1),
#  ('tonight', 1),
#  ('gotta', 1),
#  ('talk', 1),
#  ('wanna', 1),
#  ('lets', 1),
#  ('yall', 1),
#  ('ive', 1),
#  ('big', 1),
#  ('husband', 1),
#  ('baby', 1),
#  ('let', 1),
#  ('remember', 1),
#  ('ok', 1),
#  ('knew', 1),
#  ('goddammit', 1),
#  ('cats', 1),
#  ('fucked', 1),
#  ('jesus', 1),
#  ('man', 1),
#  ('god', 1),
#  ('red', 1),
#  ('fun', 1),
#  ('special', 1),
#  ('mom', 1),
#  ('gay', 1),
#  ('woman', 1),
#  ('bethlehem', 1),
#  ('comedy', 1),
#  ('buddy', 1),
#  ('trust', 1),
#  ('country', 1),
#  ('trying', 1),
#  ('magician', 1),
#  ('israel', 1),
#  ('political', 1),
#  ('crowd', 1),
#  ('palestine', 1),
#  ('believe', 1),
#  ('dude', 1),
#  ('dad', 1),
#  ('funny', 1),
#  ('news', 1),
#  ('white', 1),
#  ('fox', 1),
#  ('night', 1),
#  ('trump', 1),
#  ('pretty', 1),
#  ('nice', 1),
#  ('sex', 1)]

# %%
# Let's isolate just these bad words
data_bad_words = data.transpose()[['fucking', 'fuck', 'shit']]
data_profanity = pd.concat([data_bad_words.fucking + data_bad_words.fuck, data_bad_words.shit], axis=1)
data_profanity.columns = ['f_word', 's_word']
data_profanity
# Out:
#           f_word  s_word
# david          0       0
# gabriel        6      18
# george         0      23
# jon            0       0
# kate           0       1
# kevin          0       0
# leanne         0       2
# lewis        113      23
# louis         56      10
# matt          77      25
# pete          62       8
# roseanne       6      24
# sammy          0       1
# shane          0      12
# stavros        1       0

# %%
# Let's create a scatter plot of our findings
plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity.index):
    x = data_profanity.f_word.loc[comedian]
    y = data_profanity.s_word.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x+1.5, y+0.5, full_names[i], fontsize=10)
    plt.xlim(-5, 155) 
    
plt.title('Number of Bad Words Used in Routine', fontsize=20)
plt.xlabel('Number of F Bombs', fontsize=15)
plt.ylabel('Number of S Words', fontsize=15)

plt.show()

# %% [markdown]
# ### Findings

# %% [markdown]
# * **Averaging 2 F-Bombs Per Minute!** - I don't like too much swearing, especially the f-word, which is probably why I've never heard of Bill Bur, Joe Rogan and Jim Jefferies.
# * **Clean Humor** - It looks like profanity might be a good predictor of the type of comedy I like. Besides Ali Wong, my two other favorite comedians in this group are John Mulaney and Mike Birbiglia.

# %% [markdown]
# ## Side Note

# %% [markdown]
# What was our goal for the EDA portion of our journey? **To be able to take an initial look at our data and see if the results of some basic analysis made sense.**
#
# My conclusion - yes, it does, for a first pass. There are definitely some things that could be better cleaned up, such as adding more stop words or including bi-grams. But we can save that for another day. The results, especially the profanity findings, are interesting and make general sense, so we're going to move on.
#
# As a reminder, the data science process is an interative one. It's better to see some non-perfect but acceptable results to help you quickly decide whether your project is a dud or not, instead of having analysis paralysis and never delivering anything.
#
# **Alice's data science (and life) motto: Let go of perfectionism!**

# %% [markdown]
# ## Additional Exercises

# %% [markdown]
# 1. What other word counts do you think would be interesting to compare instead of the f-word and s-word? Create a scatter plot comparing them.

# %%
# Let's isolate new words
data_new_words = data.transpose()[['goes', 'okay']]

# Sum up the occurrences of 'goes' and 'okay'
data_profanity_new = pd.concat([data_new_words.goes, data_new_words.okay], axis=1)
data_profanity_new.columns = ['goes', 'okay']
data_profanity_new
# Out:
#           goes  okay
# david        6     6
# gabriel      9    49
# george       6     0
# jon          0     2
# kate         2    67
# kevin       37    16
# leanne       3    30
# lewis        1     0
# louis        5    19
# matt         3    40
# pete        63    25
# roseanne    10     0
# sammy        0     1
# shane        1     3
# stavros      4    18

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

for i, comedian in enumerate(data_profanity_new.index):
    x = data_profanity_new.goes.loc[comedian]
    y = data_profanity_new.okay.loc[comedian]
    plt.scatter(x, y, color='blue')
    plt.text(x + 1.5, y + 0.5, full_names[i], fontsize=7)  
    plt.xlim(-10, 100)  # Adjust x-axis limits as needed
    
plt.title('New Words Used', fontsize=20)
plt.xlabel('Number of "goes" Words', fontsize=15)
plt.ylabel('Number of "okay" Words', fontsize=15)

plt.show()
